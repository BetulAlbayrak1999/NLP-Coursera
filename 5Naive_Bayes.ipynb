# %% [markdown]
# ### Naive Bayes
# Will be using Naive Bayes for sentiment analysis on tweets. Given a tweet, we will decide if it has a positive sentiment or a negative one. Specifically we will:
#
# - Train a naive bayes model on a sentiment analysis task
# - Test using our model
# - Compute ratios of positive words to negative words
# - Do some error analysis
# - Predict on your own tweet

# %% [markdown]
# ### Importing Functions and Data

# %%
import re
import string

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer

from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms

import numpy as np

# %%
import pdb
from nltk.corpus import stopwords, twitter_samples
import numpy as np
import pandas as pd
import nltk
from os import getcwd

nltk.download('twitter_samples')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package twitter_samples to /root/nltk_data...
# [nltk_data]   Unzipping corpora/twitter_samples.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def process_tweet(tweet):
  """
  Input:
    tweet: a string contain a tweet
  Output:
    tweets_clean: a list of words containing the processed tweet
  """

  stemmer= PorterStemmer()
  stopwords_english= stopwords.words('english')

  # remove stock market tickes like $GE
  tweet= re.sub(r'\$\w*', '', tweet)

  #remove old style retweet text "RT"
  tweet= re.sub(r'^RT[\s]+', '', tweet)

  # remove hyperlink
  tweet= re.sub(r'hhtps?://[^/s/n/r]+', '', tweet)

  #remove hashtag
  tweet= re.sub(r'#', '', tweet)

  # tokenize tweet
  tokenizer= TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)

  tweet_tokens= tokenizer.tokenize(tweet)

  tweets_clean= []
  for word in tweet_tokens:
    if (word not in stopwords_english and word not in string.punctuation):
      stem_word= stemmer.stem(word)
      tweets_clean.append(stem_word)

  return tweets_clean

# %%
def test_lookup(func):
  freqs= {('sad', 0): 4,
          ('happy', 1): 3,
          ('oppressed', 0): 3
          }
  word= 'happy'
  label= 1
  if func(freqs, word, label)==3:
    return 'Success'
  return 'Failed'

# %%
def lookup(freqs, word, label):
  """
    Input:
      freqs: a dictionary with the frequency of each pair (or tuple)
      word: the word to look up
      label: the label corresponding to the word
    Output:
      n: the number od times the word with its corresponding label appears.
  """
  n = 0 # freqs.get((word, label), 0)

  pair= (word, label)
  if (pair in freqs):
    n= freqs[pair]

  return n

# %%
def confidence_ellipse(x, y, ax, n_std=3.0, facecolor='none', **kwargs):
  """
    Create a plot of the covariance confidence ellipse of `x` and `y`

    Input:
      x, y: array_like, shape(n, )
        Input data.
      ax: matplotlib.axes.Axes
        The axes object to draw the ellipse into.
      n_std: float
        The number of standard deviation to determine the sllipse's radiuses.

    Output:
      matplotlib.patches.Ellipse
      kwargs: `matplotlib.patches.Patch` properties

  """
  if x.size != y.size:
    raise ValueError("x and y must be the same size")

  cov = np.cov(x, y)
  pearson= cov[0, 1]/np.sqrt(cov[0, 0] * cov[1, 1])
  # Using a special case to obtain the eigenvalues of this
  # two-dimensionl dataset.
  ell_radius_x = np.sqrt(1 + pearson)
  ell_radius_y = np.sqrt(1 - pearson)
  ellipse = Ellipse((0, 0),
                    width=ell_radius_x * 2,
                    height=ell_radius_y * 2,
                    facecolor=facecolor,
                    **kwargs)

  # Calculating the stdandard deviation of x from
  # the squareroot of the variance and multiplying
  # with the given number of standard deviations.
  scale_x = np.sqrt(cov[0, 0]) * n_std
  mean_x = np.mean(x)

  # calculating the stdandard deviation of y ...
  scale_y = np.sqrt(cov[1, 1]) * n_std
  mean_y = np.mean(y)

  transf = transforms.Affine2D() \
      .rotate_deg(45) \
      .scale(scale_x, scale_y) \
      .translate(mean_x, mean_y)

  ellipse.set_transform(transf + ax.transData)
  return ax.add_patch(ellipse)

# %%
filePath= f"{getcwd()}/../tmp2/"
nltk.data.path.append(filePath)

# %%
# get the set of positive and negative tweets
all_positive_tweets= twitter_samples.strings('positive_tweets.json')
all_negative_tweets= twitter_samples.strings('negative_tweets.json')

# split the data into two pieces, one for training and one for testing(validation set)
test_pos= all_positive_tweets[4000:]
train_pos= all_positive_tweets[:4000]
test_neg= all_negative_tweets[4000:]
train_neg= all_negative_tweets[:4000]

train_x= train_pos + train_neg
test_x= test_pos + test_neg

# avoid assumptions about the length of all_positive_tweets and all_negative_tweets
train_y= np.append(np.ones(len(train_pos)), np.zeros(len(train_neg)))
test_y= np.append(np.ones(len(test_pos)), np.zeros(len(test_neg)))

# %% [markdown]
# ### 1- Process the Data
# For any machine learning project, once we've gathered the data, the first step is to process it to make useful inputs to our model.
#
# - Remove noise: You will first want to remove noise from our data -- that is, remove words that don't tell us much about the content. These include all common words like 'I, you, are, is, etc...' that would not give us enough information on the sentiment.
# - We'll also remove stock market tickers, retweet symbols, hyperlinks, and hashtags because they can not tell us a lot of information on the sentiment.
# - You also want to remove all the punctuation from a tweet. The reason for doing this is because we want to treat words with or without the punctuation as the same word, instead of treating "happy", "happy?", "happy!", "happy," and "happy." as different words.
# - Finally we want to use stemming to only keep track of one variation of each word. In other words, we'll treat "motivation", "motivated", and "motivate" similarly by grouping them within the same stem of "motiv-".
#
#
# We have given the function `process_tweet` that does this for us.

# %%
custom_tweet= "RT @Twitter @chapagain Hello There! Have a great day. :)  #good #morning http://chapagain.com.np"

#print cleaned tweet
print(process_tweet(custom_tweet))
# Out:
# ['hello', 'great', 'day', ':)', 'good', 'morn', 'http://chapagain.com.np']

# %% [markdown]
# ### 1.1- Implementing Our Helper Function
#
# To help you train your naive bayes model, you will need to compute a dictionary where the keys are a tuple (word, label) and the values are the corresponding frequency. Note that the labels we'll use here are 1 for positive and 0 for negative.
#
# You will also implement a lookup helper function that takes in the `freqs` dictionary, a word, and a label (1 or 0) and returns the number of times that word and label tuple appears in the collection of tweets.
#
# For example: given a list of tweets `["i am rather excited", "you are rather happy"]`  and the label 1, the function will return a dictionary that contains the following key-value pairs:
#
# `{ ("rather", 1): 2, ("happi", 1) : 1, ("excit", 1) : 1 }`
#
# - Notice how for each word in the given string, the same label 1 is assigned to each word.
# - Notice how the words "i" and "am" are not saved, since it was removed by process_tweet because it is a stopword.
# - Notice how the word "rather" appears twice in the list of tweets, and so its count value is 2.

# %% [markdown]
# ### Count_tweets
# Create a function `count_tweets` that takes a list of tweets as input, cleans all of them, and returns a dictionary.
#
# The key in the dictionary is a tuple containing the stemmed word and its class label, e.g. ("happi",1).
# The value the number of times this word appears in the given collection of tweets (an integer).

# %%
def count_tweets(result, tweets, ys):
  """
    Input:
      result: a dictionary that will be used to map each pair to its frequency
      tweets: a list of tweets
      ys: a list corresponding to the sentiment of each tweet (either 0 or 1)
    Output:
    result:  a dictionary mapping each pair to its frequency
  """
  for y, tweet in zip(ys, tweets):
    for word in process_tweet(tweet):
      #define the key which is the word and label tuple
      pair= (word, y)

      #if the key exits inb the dictionary, incement the count
      if pair in result:
        result[pair]+= 1
      #else add it to the dictionary and set the count to 1
      else:
        result[pair]= 1

  return result

# %%
# Testing the function
result= {}
tweets= ["i am not happy and beautiful", "i am tricked", "i am sad", "i am tired", "i am tired"]
ys= [1, 0, 0, 0, 0]
count_tweets(result, tweets, ys)
# Out:
# {('happi', 1): 1,
#  ('beauti', 1): 1,
#  ('trick', 0): 1,
#  ('sad', 0): 1,
#  ('tire', 0): 2}

# %% [markdown]
# <a name='2'></a>
# ### Train Our Model using Naive Bayes
#
# Naive bayes is an algorithm that could be used for sentiment analysis. It takes a short time to train and also has a short prediction time.
#
# #### So how do you train a Naive Bayes classifier?
# - The first part of training a naive bayes classifier is to identify the number of classes that you have.
# - You will create a probability for each class.
# $P(D_{pos})$ is the probability that the document is positive.
# $P(D_{neg})$ is the probability that the document is negative.
# Use the formulas as follows and store the values in a dictionary:
#
# $$P(D_{pos}) = \frac{D_{pos}}{D}\tag{1}$$
#
# $$P(D_{neg}) = \frac{D_{neg}}{D}\tag{2}$$
#
# Where $D$ is the total number of documents, or tweets in this case, $D_{pos}$ is the total number of positive tweets and $D_{neg}$ is the total number of negative tweets.

# %% [markdown]
# #### Prior and Logprior
#
# The prior probability represents the underlying probability in the target population that a tweet is positive versus negative.  In other words, if we had no specific information and blindly picked a tweet out of the population set, what is the probability that it will be positive versus that it will be negative? That is the "prior".
#
# The prior is the ratio of the probabilities $\frac{P(D_{pos})}{P(D_{neg})}$.
# We can take the log of the prior to rescale it, and we'll call this the logprior
#
# $$\text{logprior} = log \left( \frac{P(D_{pos})}{P(D_{neg})} \right) = log \left( \frac{D_{pos}}{D_{neg}} \right)$$.
#
# Note that $log(\frac{A}{B})$ is the same as $log(A) - log(B)$.  So the logprior can also be calculated as the difference between two logs:
#
# $$\text{logprior} = \log (P(D_{pos})) - \log (P(D_{neg})) = \log (D_{pos}) - \log (D_{neg})\tag{3}$$

# %% [markdown]
# #### Positive and Negative Probability of a Word
# To compute the positive probability and the negative probability for a specific word in the vocabulary, we'll use the following inputs:
#
# - $freq_{pos}$ and $freq_{neg}$ are the frequencies of that specific word in the positive or negative class. In other words, the positive frequency of a word is the number of times the word is counted with the label of 1.
# - $N_{pos}$ and $N_{neg}$ are the total number of positive and negative words for all documents (for all tweets), respectively.
# - $V$ is the number of unique words in the entire set of documents, for all classes, whether positive or negative.
#
# We'll use these to compute the positive and negative probability for a specific word using this formula:
#
# $$ P(W_{pos}) = \frac{freq_{pos} + 1}{N_{pos} + V}\tag{4} $$
# $$ P(W_{neg}) = \frac{freq_{neg} + 1}{N_{neg} + V}\tag{5} $$
#
# Notice that we add the "+1" in the numerator for additive smoothing.  This [wiki article](https://en.wikipedia.org/wiki/Additive_smoothing) explains more about additive smoothing.

# %% [markdown]
# #### Log likelihood
# To compute the loglikelihood of that very same word, we can implement the following equations:
#
# $$\text{loglikelihood} = \log \left(\frac{P(W_{pos})}{P(W_{neg})} \right)\tag{6}$$

# %%
# Build the freqs dictionary for later uses
freqs= count_tweets({}, train_x, train_y)

# %% [markdown]
# <a name='ex-2'></a>
# ### Train_naive_bayes
# Given a freqs dictionary, `train_x` (a list of tweets) and a `train_y` (a list of labels for each tweet), implement a naive bayes classifier.
#
# ##### Calculate $V$
# - You can then compute the number of unique words that appear in the `freqs` dictionary to get your $V$ (you can use the `set` function).
#
# ##### Calculate $freq_{pos}$ and $freq_{neg}$
# - Using your `freqs` dictionary, you can compute the positive and negative frequency of each word $freq_{pos}$ and $freq_{neg}$.
#
# ##### Calculate $N_{pos}$, and $N_{neg}$
# - Using `freqs` dictionary, you can also compute the total number of positive words and total number of negative words $N_{pos}$ and $N_{neg}$.
#
# ##### Calculate $D$, $D_{pos}$, $D_{neg}$
# - Using the `train_y` input list of labels, calculate the number of documents (tweets) $D$, as well as the number of positive documents (tweets) $D_{pos}$ and number of negative documents (tweets) $D_{neg}$.
# - Calculate the probability that a document (tweet) is positive $P(D_{pos})$, and the probability that a document (tweet) is negative $P(D_{neg})$
#
# ##### Calculate the logprior
# - the logprior is $log(D_{pos}) - log(D_{neg})$
#
# ##### Calculate log likelihood
# - Finally, you can iterate over each word in the vocabulary, use your `lookup` function to get the positive frequencies, $freq_{pos}$, and the negative frequencies, $freq_{neg}$, for that specific word.
# - Compute the positive probability of each word $P(W_{pos})$, negative probability of each word $P(W_{neg})$ using equations 4 & 5.
#
# $$ P(W_{pos}) = \frac{freq_{pos} + 1}{N_{pos} + V}\tag{4} $$
# $$ P(W_{neg}) = \frac{freq_{neg} + 1}{N_{neg} + V}\tag{5} $$
#
# **Note:** We'll use a dictionary to store the log likelihoods for each word.  The key is the word, the value is the log likelihood of that word).
#
# - You can then compute the loglikelihood: $log \left( \frac{P(W_{pos})}{P(W_{neg})} \right)$.

# %%
def train_naive_bayes(freqs, train_x, train_y):
  """
    Input:
      freqs: a dictionary from (word, label) to how often the word appears
      train_x: a list of tweets
      train_y: a list labels corresponding to the tweets (0, 1)
    Output:
      logprior: the log prior. (equation 3 above)
      loglikelihood: the log likelihood of you Naive bayes equation. (equation 6 above)
  """
  #pdb.set_trace()
  loglikelihood={}
  logprior= 0

  # calculate V, the number of unique words in the vocabulary
  vocab= set([pair[0] for pair in freqs.keys()])

  V= len(vocab)

  #calculate N_pos, N_neg, V_pos, V_neg
  N_pos= N_neg= 0
  for pair in freqs.keys():

    #if the label is positive (greater than zero)
    if pair[1] > 0:
      #Incement the number of positive words by the count for this (word, label) pair
      N_pos+= freqs[pair]

    #else, the label is negative
    else:
      # increment the number of negative words by the count for this (word,label) pair
      N_neg+= freqs[pair]

  #calculate D, the number of documents
  D= len(train_y)

  #calculate D_pos, the number of positive documents
  D_pos= sum(train_y)

  #calculate D_neg, the number of negative documents
  D_neg= D - D_pos

  # Calculate logprior
  logprior = np.log(D_pos / D_neg)

  # for each word in the vocabulary:
  for word in vocab:
    #get the positive and negative frequency of the word
    freq_pos= freqs.get((word, 1), 0)
    freq_neg= freqs.get((word, 0), 0)

    # calculate the probability that each word is positive, and negative
    p_w_pos = (freq_pos + 1) / (N_pos + V)
    p_w_neg = (freq_neg + 1) / (N_neg + V)

    # calculate the log likelihood of the word
    loglikelihood[word] = np.log(p_w_pos / p_w_neg)


  return logprior, loglikelihood

# %%
logprior, loglikelihood = train_naive_bayes(freqs, train_x, train_y)
print(logprior)
print(len(loglikelihood))
# Out:
# 0.0
# 10486

# %% [markdown]
# <a name='3'></a>
# ### Test Our Naive Bayes
#
# Now that we have the `logprior` and `loglikelihood`, we can test the naive bayes function by making predicting on some tweets!
#
# <a name='ex-3'></a>
# ### Naive_bayes_predict
# Implement `naive_bayes_predict`.
#
# **Instructions**:
# Implement the `naive_bayes_predict` function to make predictions on tweets.
# * The function takes in the `tweet`, `logprior`, `loglikelihood`.
# * It returns the probability that the tweet belongs to the positive or negative class.
# * For each tweet, sum up loglikelihoods of each word in the tweet.
# * Also add the logprior to this sum to get the predicted sentiment of that tweet.
#
# $$ p = logprior + \sum_i^N (loglikelihood_i)$$
#
# #### Note
# Note we calculate the prior from the training data, and that the training data is evenly split between positive and negative labels (4000 positive and 4000 negative tweets).  This means that the ratio of positive to negative 1, and the logprior is 0.
#
# The value of 0.0 means that when we add the logprior to the log likelihood, we're just adding zero to the log likelihood.  However, please remember to include the logprior, because whenever the data is not perfectly balanced, the logprior will be a non-zero value.

# %%
def naive_bayes_predict(tweet, logprior, loglikelihood):
  """
    Input:
      tweet: a string
      logprior: a number
      loglikelihood: a dictionary of words mapping to numbers
    Output:
      p: the sum of all the logliklihoods of each word in the tweet (if found in the dictionary) + logprior (a number)
  """

  # process th etweet to get a list of words
  word_list= process_tweet(tweet)

  # initialize propability to zero
  p= 0

  # add the logprior
  p+= logprior

  for word in word_list:
    # check if the word exists in the likelihood dictionary
    if word in loglikelihood:
      # add the log likelihood of that word to the probability
      p+= loglikelihood[word]

  return p

# %%
my_tweet= 'she smiled'
p= naive_bayes_predict(my_tweet, logprior, loglikelihood)
print('The expected output is', p)
# Out:
# The expected output is 1.541726096091416

# %%
# Experiment with your own tweet.
my_tweet = 'He laughed.'
p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print('The expected output is', p)
# Out:
# The expected output is -0.18104050164968757

# %% [markdown]
# <a name='ex-4'></a>
# ### Test_naive_bayes
# Implement test_naive_bayes.
#
# **Instructions**:
# * Implement `test_naive_bayes` to check the accuracy of your predictions.
# * The function takes in your `test_x`, `test_y`, log_prior, and loglikelihood
# * It returns the accuracy of your model.
# * First, use `naive_bayes_predict` function to make predictions for each tweet in text_x.

# %%
def test_naive_bayes(text_x, test_y, logprior, loglikelihood, naive_bayes_predict= naive_bayes_predict):
  """
    Input:
      test_x: A list of tweets
      test_y: the coreesponding labels for the list of tweets
      logprior: the logprior
      loglikelihood: a dictionary with the loglikelihood for each word

    Output:
      accucary: (# of tweets classified correctly) /(total # of tweets)
  """

  accuracy= 0 # return this properly

  y_hats= []
  for tweet in text_x:
      # if the prediction is > 0
      if naive_bayes_predict(tweet, logprior, loglikelihood) > 0:
          # the predicted class is 1
          y_hat_i = 1
      else:
          # otherwise the predicted class is 0
          y_hat_i = 0
      # append the predicted class to the list y_hats
      y_hats.append(y_hat_i)
  # error is the average of the absolute values of the differences between y_hats and test_y
  error = sum([abs(y_hat - y) for y_hat, y in zip(y_hats, test_y)])/len(test_y)

  # Accuracy is 1 minus the error
  accuracy= 1- error
  return accuracy

# %%
print("Naive Bayes accuracy = %0.4f" %
      (test_naive_bayes(test_x, test_y, logprior, loglikelihood)))
# Out:
# Naive Bayes accuracy = 0.9955

# %%
# Run this cell to test your function
for tweet in ['I am happy', 'I am bad', 'this movie should have been great.', 'great', 'great great', 'great great great', 'great great great great']:
    # print( '%s -> %f' % (tweet, naive_bayes_predict(tweet, logprior, loglikelihood)))
    p = naive_bayes_predict(tweet, logprior, loglikelihood)
#     print(f'{tweet} -> {p:.2f} ({p_category})')
    print(f'{tweet} -> {p:.2f}')
# Out:
# I am happy -> 2.12
# I am bad -> -1.33
# this movie should have been great. -> 2.09
# great -> 2.11
# great great -> 4.23
# great great great -> 6.34
# great great great great -> 8.45

# %% [markdown]
# <a name='4'></a>
# ### Filter words by Ratio of Positive to Negative Counts
#
# - Some words have more positive counts than others, and can be considered "more positive".  Likewise, some words can be considered more negative than others.
# - One way for us to define the level of positiveness or negativeness, without calculating the log likelihood, is to compare the positive to negative frequency of the word.
#     - Note that we can also use the log likelihood calculations to compare relative positivity or negativity of words.
# - We can calculate the ratio of positive to negative frequencies of a word.
# - Once we're able to calculate these ratios, we can also filter a subset of words that have a minimum ratio of positivity / negativity or higher.
# - Similarly, we can also filter a subset of words that have a maximum ratio of positivity / negativity or lower (words that are at least as negative, or even more negative than a given threshold).
#
# <a name='ex-5'></a>
# ### Get_ratio
# Implement get_ratio.
#
# - Given the freqs dictionary of words and a particular word, use `lookup(freqs,word,1)` to get the positive count of the word.
# - Similarly, use the `lookup` function to get the negative count of that word.
# - Calculate the ratio of positive divided by negative counts
#
# $$ ratio = \frac{\text{pos_words} + 1}{\text{neg_words} + 1} $$
#
# Where pos_words and neg_words correspond to the frequency of the words in their respective classes.
# <table>
#     <tr>
#         <td>
#             <b>Words</b>
#         </td>
#         <td>
#         Positive word count
#         </td>
#          <td>
#         Negative Word Count
#         </td>
#   </tr>
#     <tr>
#         <td>
#         glad
#         </td>
#          <td>
#         41
#         </td>
#     <td>
#         2
#         </td>
#   </tr>
#     <tr>
#         <td>
#         arriv
#         </td>
#          <td>
#         57
#         </td>
#     <td>
#         4
#         </td>
#   </tr>
#     <tr>
#         <td>
#         :(
#         </td>
#          <td>
#         1
#         </td>
#     <td>
#         3663
#         </td>
#   </tr>
#     <tr>
#         <td>
#         :-(
#         </td>
#          <td>
#         0
#         </td>
#     <td>
#         378
#         </td>
#   </tr>
# </table>

# %%
def get_ratio(freqs, word):
    '''
    Input:
        freqs: dictionary containing the words

    Output: a dictionary with keys 'positive', 'negative', and 'ratio'.
        Example: {'positive': 10, 'negative': 20, 'ratio': 0.5}
    '''
    pos_neg_ratio = {'positive': 0, 'negative': 0, 'ratio': 0.0}
    # use lookup() to find positive counts for the word (denoted by the integer 1)
    pos_neg_ratio['positive'] = lookup(freqs, word, 1)

    # use lookup() to find negative counts for the word (denoted by integer 0)
    pos_neg_ratio['negative'] = lookup(freqs, word, 0)

    # calculate the ratio of positive to negative counts for the word
    pos_neg_ratio['ratio'] = pos_neg_ratio['positive'] / (pos_neg_ratio['negative'] + 1)

    return pos_neg_ratio

# %%
get_ratio(freqs, 'happi')
# Out:
# {'positive': 162, 'negative': 18, 'ratio': 8.526315789473685}

# %% [markdown]
# <a name='ex-6'></a>
# ### Get_words_by_threshold
# Implement get_words_by_threshold(freqs,label,threshold)
#
# * If we set the label to 1, then we'll look for all words whose threshold of positive/negative is at least as high as that threshold, or higher.
# * If we set the label to 0, then we'll look for all words whose threshold of positive/negative is at most as low as the given threshold, or lower.
# * Use the `get_ratio` function to get a dictionary containing the positive count, negative count, and the ratio of positive to negative counts.
# * Append the `get_ratio` dictionary inside another dictinoary, where the key is the word, and the value is the dictionary `pos_neg_ratio` that is returned by the `get_ratio` function.
# An example key-value pair would have this structure:
# ```
# {'happi':
#     {'positive': 10, 'negative': 20, 'ratio': 0.524}
# }
# ```

# %%
def get_words_by_threshold(freqs, label, threshold, get_ratio=get_ratio):
    '''
    Input:
        freqs: dictionary of words
        label: 1 for positive, 0 for negative
        threshold: ratio that will be used as the cutoff for including a word in the returned dictionary
    Output:
        word_list: dictionary containing the word and information on its positive count, negative count, and ratio of positive to negative counts.
        example of a key value pair:
        {'happi':
            {'positive': 10, 'negative': 20, 'ratio': 0.5}
        }
    '''
    word_list = {}

    for key in freqs.keys():
        word, _ = key

        # get the positive/negative ratio for a word
        pos_neg_ratio = get_ratio(freqs, word)

        # if the label is 1 and the ratio is greater than or equal to the threshold...
        if label == 1 and pos_neg_ratio['ratio'] >= threshold:

            # Add the pos_neg_ratio to the dictionary
            word_list[word] = pos_neg_ratio

        # If the label is 0 and the pos_neg_ratio is less than or equal to the threshold...
        elif label == 0 and pos_neg_ratio['ratio'] <= threshold:

            # Add the pos_neg_ratio to the dictionary
            word_list[word] = pos_neg_ratio

        # otherwise, do not include this word in the list (do nothing)

    return word_list

# %%
# Test your function: find negative words at or below a threshold
get_words_by_threshold(freqs, label=0, threshold=0.05)
# Out:
# {'sad': {'positive': 5, 'negative': 100, 'ratio': 0.04950495049504951},
#  'ugh': {'positive': 1, 'negative': 23, 'ratio': 0.041666666666666664},
#  'sick': {'positive': 1, 'negative': 32, 'ratio': 0.030303030303030304},
#  ':(': {'positive': 1, 'negative': 3676, 'ratio': 0.0002719608376393799},
#  'x15': {'positive': 1, 'negative': 35, 'ratio': 0.027777777777777776},
#  'shame': {'positive': 1, 'negative': 19, 'ratio': 0.05},
#  'didnt': {'positive': 1, 'negative': 19, 'ratio': 0.05},
#  'hopeless': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'ikea': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'slide': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'bani': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'https://t.co/9fcwgvaki0': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'neighbour': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'motor': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'search': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'http://t.co/xvmtuikwln': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sialan': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'https://t.co/hv1i0xcrl2': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'athabasca': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'glacier': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  '1948': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  ':-(': {'positive': 0, 'negative': 386, 'ratio': 0.0},
#  'jasper': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'jaspernationalpark': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'alberta': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'explorealberta': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/dzzdqmf7cz': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'mare': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ivan': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'hahahah': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'replac': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'bi-polar': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'grasp': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'digit': {'positive': 0, 'negative': 5, 'ratio': 0.0},
#  'https://t.co/nc9lkyuuvo': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'lone': {'positive': 0, 'negative': 7, 'ratio': 0.0},
#  '😩': {'positive': 0, 'negative': 11, 'ratio': 0.0},
#  'choreograph': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/iuiaioynnx': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'mingm': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'https://t.co/q5tayjrq8k': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'truli': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'pee': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'newwin': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'doushit': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'gundam': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'dollar': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/oi0pygusdi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'pale': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'imit': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'rash': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'absent': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sequel': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ouucchhh': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'wisdom': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'frighten': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'pret': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'wkwkw': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'verfi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sentir-s': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'incompleta': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'thwart': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'zant': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  "when'": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'audraesar': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'craaazzyy': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'http://t.co/36tsy81imi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'helium': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'climatechang': {'positive': 0, 'negative': 5, 'ratio': 0.0},
#  "california'": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'influenti': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'pollut': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'watchdog': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'califor': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/ovu4p2qwfh': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'uniteblu': {'positive': 0, 'negative': 10, 'ratio': 0.0},
#  'tcot': {'positive': 0, 'negative': 9, 'ratio': 0.0},
#  'elhaida': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'juri': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '10th': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'televot': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'idaho': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'drought-link': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'die-of': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/jjbodo6lyz': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'abrupt': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'climat': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'mammoth': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'megafauna': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/tavmcz37e7': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  "australia'": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'dirtiest': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'energi': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'biomass': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/yeqabq6tsl': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'golf': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ulti': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/la82rxzts2': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'prexi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'kindergarten': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sane': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'boss': {'positive': 0, 'negative': 5, 'ratio': 0.0},
#  'hozier': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'soooner': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'respectlost': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/nt25myngyd': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'hypercholesteloremia': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'calibraska': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'genuin': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'contend': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'older': {'positive': 0, 'negative': 5, 'ratio': 0.0},
#  'https://t.co/jzbfbkld8q': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'https://t.co/pn2hvgdnft': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ao': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'yun': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'encor': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  '4thwin': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'baymax': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'mixer': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'wft': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'https://t.co/chzrqtelph': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'hub': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'loud': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'parasyt': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'alll': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'zayniscomingbackonjuli': {'positive': 0, 'negative': 19, 'ratio': 0.0},
#  '26': {'positive': 0, 'negative': 20, 'ratio': 0.0},
#  'era': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '。': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'ω': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '」': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  '∠': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'nathann': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'dieididieieiei': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'netflix': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'ervin': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'desper': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'amargolonnard': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'batalladelosgallo': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'webcamsex': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'http://t.co/3s9lhafrsu': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'duti': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  "u'v": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'alien': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sorka': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'funer': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'http://t.co/17tca0uhkp': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'nonexist': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'wowza': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'fah': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'boo': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'hyung': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'predict': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sj': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'nomin': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'brace': {'positive': 0, 'negative': 5, 'ratio': 0.0},
#  'https://t.co/znojt3v9gq': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'omggg': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'whyyi': {'positive': 0, 'negative': 6, 'ratio': 0.0},
#  'evan': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'opt': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'muster': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'merch': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'savanna': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'straw': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'yester': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'when': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'consum': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'werk': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'foreal': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'wesen': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'uwes': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'bosen': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'egg': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'benni': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'badli': {'positive': 0, 'negative': 9, 'ratio': 0.0},
#  '>:(': {'positive': 0, 'negative': 43, 'ratio': 0.0},
#  'https://t.co/ycguditqgx': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'zaz': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/2jcbiswdw9': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'rehash': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'mushroom': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'piec': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'vicki': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '45': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'hahah': {'positive': 0, 'negative': 5, 'ratio': 0.0},
#  'ninasti': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'tsktsk': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'dick': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'kawaii': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'manli': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/83cugt7qq3': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/vm4n0n8bkw': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'youu': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'potato': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'asf': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'eish': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ive': {'positive': 0, 'negative': 10, 'ratio': 0.0},
#  'lost': {'positive': 0, 'negative': 19, 'ratio': 0.0},
#  'mojo': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'mara': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'neh': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'councillor': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sholong': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'reject': {'positive': 0, 'negative': 6, 'ratio': 0.0},
#  'gee': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'gidi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'lago': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ehn': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'arrest': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'idk': {'positive': 0, 'negative': 17, 'ratio': 0.0},
#  'anybodi': {'positive': 0, 'negative': 7, 'ratio': 0.0},
#  'disappear': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'daze': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'fragment': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  "would'v": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'walao': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'djderek': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'legend': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'tragedi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '💪🏻': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '🐒': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'struck': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'belgium': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'fabian': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'delph': {'positive': 0, 'negative': 5, 'ratio': 0.0},
#  'fallen': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'drake': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'silent': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'mumma': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'pray': {'positive': 0, 'negative': 12, 'ratio': 0.0},
#  'appropri': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'across': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'hindi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '5s': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'disabl': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'pension': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ptsd': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'imposs': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'financi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'nooo': {'positive': 0, 'negative': 10, 'ratio': 0.0},
#  'toghet': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'https://t.co/gawf0bsr6a': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '21st': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'snsd': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'anna': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'akana': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'askip': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  "t'exist": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'kei': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'https://t.co/ezfehmtt5': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'kate': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'spade': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'pero': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'walang': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'agesss': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'corinehurleigh': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'snapchatm': {'positive': 0, 'negative': 5, 'ratio': 0.0},
#  'http://t.co/8bk7ptaqar': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'zara': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'trouser': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  "it'okay": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'freed': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'orcalov': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'https://t.co/toszmoafv6': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/xtszpi9fqw': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'lew': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'crumbl': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'mcflurri': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'cabl': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  "venus'": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'concept': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'rli': {'positive': 0, 'negative': 5, 'ratio': 0.0},
#  'tagal': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/qdsvs5q9sr': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'appoint': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'cereal': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'http://t.co/fvv9y3wx2o': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'previou': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  '73': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'fansign': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'expens': {'positive': 0, 'negative': 7, 'ratio': 0.0},
#  'zzzz': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  "bff'": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  "deosn't": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'liverpool': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'lowest': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'tacki': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'haaretz': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'israel': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'syria': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'chemic': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'wsj': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'rep': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/3c5prchkqw': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'wong': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'confisc': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'icepack': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'dose': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'whimper': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'senpai': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'buttsex': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  "dn't": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'brk': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  ":'(": {'positive': 0, 'negative': 12, 'ratio': 0.0},
#  'falsetto': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'zone': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'loveofmylif': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/tyhwg534ng': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  's2': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'untruth': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ij': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '💥': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '💫': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'https://t.co/vkvoxiaeqn': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'soshi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'buttt': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'heyyy': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'yeol': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'dancee': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'nemanja': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'vidic': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'roma': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/ksdgy0ltpf': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/fplkjpxnqn': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  "mom'": {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'linguist': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  "dad'": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'dumbest': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/y9waxvqkpg': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'crash': {'positive': 0, 'negative': 6, 'ratio': 0.0},
#  'resourc': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'vehicl': {'positive': 0, 'negative': 5, 'ratio': 0.0},
#  'ayex': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'lamon': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/cfoxw5wljz': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'scroll': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'curv': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'cement': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '10.3': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'https://t.co/y45q9gaj5j': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'jmu': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'camp': {'positive': 0, 'negative': 7, 'ratio': 0.0},
#  'teas': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'awuna': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'mbulelo': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'although': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'plug': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'fuse': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'dammit': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'carlton': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'aflblueshawk': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  "alex'": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'motorsport': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'cheeki': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'seo': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'nl': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'christi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'niec': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'bloodi': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'sandwhich': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'buset': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'https://t.co/hq4y4fkniz': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'discrimin': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'pregnanc': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'foot': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'f': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'http://t.co/ey9mmasmsd': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'matern': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'kick': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'http://t.co/2wt4yymnwz': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'domesticviol': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'domest': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'violenc': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'victim': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  '98fm': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/eoismrzlpo': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'vaw': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'govern': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sapiosexu': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'beta': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'hogan': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'scrub': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'wwe': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'iren': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'naa': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sold': {'positive': 0, 'negative': 5, 'ratio': 0.0},
#  'h_my_k': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'valentin': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'et': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  "r'ship": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'btwn': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'homo': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'biphob': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'disciplin': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'incl': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'european': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'lang': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'fresherstofin': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '💔': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'realist': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'benzema': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'hahahahahaah': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'donno': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'russian': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'waaa': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'eidwithgrof': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'boreddd': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'mug': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'tiddler': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '에이핑크': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  '더쇼': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'clan': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'slot': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'pfff': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'bugbounti': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'self-xss': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'header': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'poison': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'execut': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ktksbye': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'cancel': {'positive': 0, 'negative': 10, 'ratio': 0.0},
#  'petit': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '600': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'odoo': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'partner': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'effin': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ap': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'elsewher': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'branch': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/asq9nn4axr': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'pod': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'd;': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'talk-kama': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'hawako': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'waa': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'kimaaani': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'prisss': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'baggag': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'sugar': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'agh': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'undercoverboss': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'تكفى': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ach': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'wrist': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ligo': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'dozen': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'shark': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'https://t.co/s8cq6c91ni': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'heartach': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'zayniscomingback': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'sweden': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'elmhurst': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'etid': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  "chillin'with": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'father': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'istanya': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '2suppli': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'infrastructur': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'nurs': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'paramed': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'countless': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '2cope': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/93z6wovos9': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'pasha': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'plea': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'arian': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'kendal': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'kyli': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  "kylie'": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'manila': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'jeebu': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'reabsorbt': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'abscess': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'crown': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ooouch': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'barney': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'https://t.co/5zawc5z37j': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  "be'": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'problemat': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'mess': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'maa': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'bangalor': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'lui': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'manzano': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'shaaa': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'conven': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '2:30': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'delet': {'positive': 0, 'negative': 5, 'ratio': 0.0},
#  'airfield': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'jet': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  "jack'": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  "mommy'": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'overweight': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sigeg': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'habhab': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'masud': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'kaha': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'akong': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/rz52eutzmd': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/nvx057pfzp': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'pala': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'dolphin': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/rjbaffsmbh': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'holi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'anythin': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'bewar': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'agonis': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'https://t.co/b8ttz1wbkg': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'modimo': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'tseba': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'wena': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'fela': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/mqysswdot7': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'nowt': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'willi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'gon': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'vomit': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'bowl': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/5grpttmx8k': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'devast': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'titan': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ae': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/zzwd8hdcoi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'shini': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'wavi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'emo': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'http://t.co/qx7xo8x5zq': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'germani': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'shed': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'bheyp': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ayemso': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/zudftknvcm': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'swell': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'wut': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'viciou': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'simpson': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'singapor': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'http://t.co/6t9xkgtwtm': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'spinorbinmusicxcodysimpson': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'pooo': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'bh3': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'pitchwar': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'chap': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  "mine'": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'transcript': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  "apma'": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'timw': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'vitamin': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'healthier': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'stretch': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'https://t.co/hibjz4fc2r': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'blockjam': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  "schedule'": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'whack': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'thelock': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '76': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'hotgirl': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'http://t.co/dn6agzcphd': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ghantay': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'nai': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'hay': {'positive': 0, 'negative': 7, 'ratio': 0.0},
#  'deni': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'laguna': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'exit': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'gomen': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'grew': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'inch': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'http://t.co/oyt8wmo7w9': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'suuuper': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/hovzi9wqnx': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '65': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'inact': {'positive': 0, 'negative': 6, 'ratio': 0.0},
#  'orphan': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'whaaat': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'kaya': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'naaan': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'paus': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '3:30': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'inglewood': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ummm': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'charcoal': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'mid-end': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'noooo': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'rodfanta': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'wasp': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'sting': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'avert': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'exo': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'http://t.co/ghsa262orm': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'seekli': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'riptito': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'manbearpig': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'academ': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/2bhfr9bu26': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'exclus': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'unfair': {'positive': 0, 'negative': 5, 'ratio': 0.0},
#  'esp': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'bleak': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'german': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'chart': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'pfft': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'polaroid': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'newbethvideo': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'greec': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'xur': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'imi': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'stud': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'hund': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/jgb5w5ct7t': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '3.4': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'yach': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'huvvft': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'https://t.co/nrzfh7roja': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'zoo': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'fieldtrip': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/rztm0vkilm': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sizw': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'boredom': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/nu0pmygku9': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'who': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sins': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'somehow': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'tini': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'barbel': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ps': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'looong': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/wn3169k7kb': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'litro': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'shepherd': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'lami': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'lungomar': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'pesaro': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'giachietittiwed': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'igersoftheday': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'summertim': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'https://t.co/ihfcehoxl3': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'nose': {'positive': 0, 'negative': 7, 'ratio': 0.0},
#  'scarf': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'afford': {'positive': 0, 'negative': 7, 'ratio': 0.0},
#  'woe': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'nigga': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'motn': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'make-up': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/nkza8s687n': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ver': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'huhuhu': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  "m'ladi": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'j8': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'j11': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'm20': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'acad': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'schedul': {'positive': 0, 'negative': 7, 'ratio': 0.0},
#  'nowww': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'hugh': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'paw': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'muddi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'heyi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'cupcak': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'https://t.co/lgqrwfftio': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'talaga': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'poppin': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'joc': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'playin': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/rgnnyzc31c': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'subj': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sobrang': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'bv': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'zamn': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'afropunk': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'fest': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'shithous': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ladder': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'wrack': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'booset': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'restart': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'assassin': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'creed': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ii': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'heap': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/nwrirgsq8v': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ankl': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'puddl': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'slipper': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'eve': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sararoc': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/egum20htok': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'anywayhedidanicejob': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '😞': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'local': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'https://t.co/vvltlmosq0': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'cruis': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'wail': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'wheelchair': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '26week': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sbenu': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sasin': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'anarchi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'candl': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'forehead': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'medicin': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'hoya': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'mah': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'a': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'hush': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'gurli': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'purti': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'closer': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'shiver': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'paid': {'positive': 0, 'negative': 8, 'ratio': 0.0},
#  'properli': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'gol': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'pea': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'tierd': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  "eye'": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'thnkyouuu': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'highlight': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'courag': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'fishi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'idek': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'apink': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'bulet': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'gendut': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'noo': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'hotwheel': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ms': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'patch': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ahaha': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'akon': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'nightmar': {'positive': 0, 'negative': 7, 'ratio': 0.0},
#  'mino': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'crazyyi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'thooo': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'zz': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'straight': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'soundcheck': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'antagonist': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ob': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'phantasi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/du7z6cjyvm': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/uwldcqkcoq': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sleepdepriv': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'tiredashel': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '4aspot': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  "kinara'": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'awami': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/t47brjzsz5': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'niqqa': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'pb.contest': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'aarww': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'lmbo': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'dangit': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ohmygod': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'scenario': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'tooo': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'baechyyi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'okayyy': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/dn83ghow3i': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'noon': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'drag': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'serious': {'positive': 0, 'negative': 9, 'ratio': 0.0},
#  'misundersrand': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'chal': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'raha': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'yhm': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'edsa': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'jasmingarrick': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'milf': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'nakamaforev': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'kiksex': {'positive': 0, 'negative': 5, 'ratio': 0.0},
#  'http://t.co/j0ggccw3dg': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  "unicef'": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'fu': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'alon': {'positive': 0, 'negative': 12, 'ratio': 0.0},
#  'stephen': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'frustrat': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'woza': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'https://t.co/yj6ngrl5ad': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'senight': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '468': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'amateur': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'hotscratch': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/1kmyuz66rn': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sock': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  '150-160': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'peso': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/jylqwawiog': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'degrassi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'bcz': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'kat': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'chem': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'onscreen': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ofscreen': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ironi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'rhisfor': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'camsex': {'positive': 0, 'negative': 5, 'ratio': 0.0},
#  'http://t.co/ldbydfruxa': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/mcvojhpvlv': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'fxhelp': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'poopi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'pip': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'uff': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '1.300': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'glue': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'kuchar': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'up': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'uni': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'ee': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'tommi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'georgia': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'transmiss': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'orang': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'suma': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'shouldeeerr': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'repack': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'grown': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'dy': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'rihanna': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ging': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'adida': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'pro@illamasqua.com': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ifeely': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'harder': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'ratbaglat': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'semest': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'gin': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'gut': {'positive': 0, 'negative': 10, 'ratio': 0.0},
#  'reynold': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'dessert': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'villag': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'oppress': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'afghanistn': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'war': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'tore': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sunggyu': {'positive': 0, 'negative': 5, 'ratio': 0.0},
#  'injur': {'positive': 0, 'negative': 6, 'ratio': 0.0},
#  'plaster': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'rtd': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'https://t.co/0founk2onj': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'stadium': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'welder': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'hogo': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'vishaya': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'adu': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'bjp': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'madatt': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'anta': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'vishwa': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ne': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'illa': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'wua': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'picki': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/7iiyopytxl': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'thent': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '423': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sexual': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'http://t.co/vcrhadoqpt': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sync': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'plug.dj': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'suspems': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'cope': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'offroad': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'harvest': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'machineri': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'inapropri': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'weav': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'scottish': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'footbal': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'dire': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'nomoney': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'nawf': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'becho': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/br36tjvynd': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'overli': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'zap': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'distress': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'cinema': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'louisianashoot': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'har': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'chum': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ncc': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ph': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'kayo': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'itong': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'thaaat': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ctto': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/yilattpk6w': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'expir': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'bi': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  '3:33': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'jfc': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'bodo': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'amat': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'yelaaa': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'dublin': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'http://t.co/ezrfqqlzxc': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'potter': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'pine': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'keybind': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'warfar': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'diagnos': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'wiv': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  "scheuermann'": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'diseas': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'rlyhurt': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'howdo': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'georgesampson': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'signal': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'http://t.co/if9jbn3cgm': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'reckon': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  't20': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'taunton': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/1q9ezygwxi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'justiceforsandrabland': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'sandrabland': {'positive': 0, 'negative': 5, 'ratio': 0.0},
#  'disturb': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'https://t.co/k17rqtubeh': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'happpi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'justinbieb': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'daianerufato': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'ilysm': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  '07:34': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'delphi': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'dom': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'techniqu': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'https://t.co/5wyrdvjzsf': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'minc': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'symphoni': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'joe': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'wth': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'aisyhhh': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'https://t.co/16poubmvlx': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'bald': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'seungchan': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'aigooo': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'riri': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'vet': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'kept': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'lumin': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'z': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'bebee': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'lt': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'inaccuraci': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'inaccur': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'tragic': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'toronto': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'stuart': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  "party'": {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'iyalaya': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  ';(': {'positive': 0, 'negative': 5, 'ratio': 0.0},
#  'happier': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ubusi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'gymnast': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'aahhh': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/qftlz2cl0w': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'noggin': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'bump': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'feelslikeanidiot': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'pregnant': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'dearli': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'suk': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'scone': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'outnumb': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'eri': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'geez': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'preciou': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'hive': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'vietnam': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'dunt': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sob': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'http://t.co/daoz0uaqgc': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'http://t.co/hhhwqq1nh3': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'buff': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'deactiv': {'positive': 0, 'negative': 5, 'ratio': 0.0},
#  "shady'": {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'isibaya': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  '😓': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'http://t.co/fwdwyovepv': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'colder': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'med': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sausag': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'adio': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'h8': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'messeng': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'shittier': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'leno': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ident': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'crisi': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'roommat': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'nighter': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'flew': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'wetherspoon': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'polic': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'lisah': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'eboni': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'http://t.co/zvtysy29uk': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'polka': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ndi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'leftov': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'walnut': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  ...}

# %% [markdown]
# <a name='5'></a>
# ### Error Analysis
#
# In this part you will see some tweets that your model missclassified. Why do you think the missclassifications happened? Were there any assumptions made by your naive bayes model?

# %%
# Some error analysis done for you
print('Truth Predicted Tweet')
for x, y in zip(test_x, test_y):
    y_hat = naive_bayes_predict(x, logprior, loglikelihood)
    if y != (np.sign(y_hat) > 0):
        print('%d\t%0.2f\t%s' % (y, np.sign(y_hat) > 0, ' '.join(
            process_tweet(x)).encode('ascii', 'ignore')))
# Out:
# Truth Predicted Tweet
# 1	0.00	b'truli later move know queen bee upward bound movingonup'
# 1	0.00	b'new report talk burn calori cold work harder warm feel better weather :p'
# 1	0.00	b'harri niall 94 harri born ik stupid wanna chang :d https://t.co/ghat8zdaff'
# 1	0.00	b'park get sunlight'
# 1	0.00	b'uff itna miss karhi thi ap :p'
# 0	1.00	b'hello info possibl interest jonatha close join beti :( great'
# 0	1.00	b'u prob fun david'
# 0	1.00	b'pat jay'
# 0	1.00	b'sr financi analyst expedia inc bellevu wa http://t.co/ktknmhvwci financ expediajob job job hire'
